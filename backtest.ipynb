# %%
# 把1分K線資料轉換為日K線資料 output 原始
import os
import pandas as pd
from trade import TradingStrategy
from datetime import timedelta
import numpy as np

# %%
# 根目錄路徑
root_folder = "data"

# 股票清單

stock_list = ["2308","2303","2317","2330","2382","2454","2881","2882","2891","3711"]
# 年份清單
year_list = ["2023","2024"]

# %%
# 初始化所有資料的列表
all_data = []

# 遍歷股票清單
for stock in stock_list:
    stock_folder = os.path.join(root_folder, stock + "_kbars")
    if not os.path.exists(stock_folder):
        print(f"Stock folder {stock} does not exist.")
        continue

    # 遍歷年份清單
    for year in year_list:
        year_folder = os.path.join(stock_folder, year)
        if not os.path.exists(year_folder):
            print(f"Year folder {year} for stock {stock} does not exist.")
            continue

        # 遍歷年份資料夾中的所有檔案
        for file_name in os.listdir(year_folder):
            if file_name.endswith("_1min.csv"):
                file_path = os.path.join(year_folder, file_name)
                try:
                    # 讀取檔案
                    df = pd.read_csv(file_path)

                    # 檢查資料是否有內容
                    if df.empty:
                        continue

                    # 確保必要欄位存在
                    required_columns = ['date', 'open', 'high', 'low', 'close', 'volume', 'tic']
                    if not all(col in df.columns for col in required_columns):
                        print(f"File {file_name} is missing required columns.")
                        continue

                    # 將 'date' 欄位轉換為 datetime 格式
                    df['date'] = pd.to_datetime(df['date'])

                    # 排序資料，避免時間順序錯亂
                    df.sort_values(by='date', inplace=True)

                    # 檢查並填補缺失的時間資料
                    filled_data = []
                    for i in range(len(df) - 1):
                        current_row = df.iloc[i]
                        next_row = df.iloc[i + 1]
                        filled_data.append(current_row)

                        # 計算時間差
                        time_diff = next_row['date'] - current_row['date']
                        if time_diff > timedelta(minutes=1):
                            # 補上缺失的資料
                            missing_time = current_row['date'] + timedelta(minutes=1)
                            while missing_time < next_row['date']:
                                missing_row = current_row.copy()
                                missing_row['date'] = missing_time
                                filled_data.append(missing_row)
                                missing_time += timedelta(minutes=1)

                    # 添加最後一筆資料
                    filled_data.append(df.iloc[-1])

                    # 轉換回 DataFrame
                    df_filled = pd.DataFrame(filled_data)

                    # 添加到所有資料的列表
                    all_data.append(df_filled)

                except Exception as e:
                    print(f"Error processing file {file_name} in {year_folder}: {e}")

                except Exception as e:
                    print(f"Error processing file {file_name} in {year_folder}: {e}")

# 合併所有資料
if all_data:
    combined_data = pd.concat(all_data, ignore_index=True)
    print("All minute-level data loaded successfully.")

    # 將資料轉換為 NumPy 陣列
    numpy_data = combined_data.to_numpy()
    print("Data successfully converted to NumPy array.")
else:
    numpy_data = np.array([])
    print("No valid data found.")
# Out:
# All minute-level data loaded successfully.
# Data successfully converted to NumPy array.

# %%
# 回測功能實現
def backtest(start_date, end_date, year):
    flag = False
    trade = TradingStrategy(model_path="model/LSTM_v3.pt", length=10)
    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)

    # 提取日期部分，便於比對
    combined_data['date_only'] = combined_data['date'].dt.date

    # 按日期和時間排序
    combined_data.sort_values(by=['date_only', 'date'], inplace=True)

    # 生成回測分鐘範圍 (假設每天交易時間為 9:00 ~ 13:30)
    skip_date = None  # 記錄需要跳過的日期
    for current_time in pd.date_range(start=start_date, end=end_date, freq='min'):
        # 如果當天被標記為跳過，則直接略過
        if skip_date and current_time.date() == skip_date:
            continue

        # 檢查是否在交易時間範圍內
        if current_time.time() < pd.Timestamp("09:01").time() or current_time.time() > pd.Timestamp("13:30").time():
            continue
        if current_time.time() == pd.Timestamp("09:01").time():
            flag = False
        if flag:
            continue 
        # print(f"Processing for time {current_time}...")
        
        
       
        

        # 按股票分組進行回測
        time_data = []
        for stock in stock_list:
            stock_data = combined_data[combined_data['tic'] == stock + '.TW']

            if stock_data.empty:
                continue

            # 獲取指定時間的資料
            stock_time_data = stock_data[stock_data['date'] == current_time]

            if not stock_time_data.empty:
                time_data.append(stock_time_data.iloc[0])

        # 檢查是否連續兩筆資料缺失
        if len(time_data) == 0:
            if skip_date == current_time.date():
                continue  # 已經標記過則跳過
            if skip_date is None:
                skip_date = current_time.date()  # 標記當前日期
                continue

        # 如果該時間點有資料，重置跳過日期
        skip_date = None

        if len(time_data) != len(stock_list) and len(time_data) != 0:
            print(time_data)
            raise ValueError("error processing for stock_length")

        # 如果該時間點有資料，傳遞給策略函數
        if time_data:
            trade.data_load(time_data)
        if current_time.time() > pd.Timestamp("09:30").time():
            if len(trade.pay_data) == 0:
                flag =True
        
        
    data = trade.trade
    df = pd.DataFrame(data)
    df.to_csv( year+"output.csv", index=False)



# 執行回測2024-12-15
backtest(start_date="2023-01-01", end_date="2023-12-31",year="2023")
# Out:
# 日期變更，清空已存資料: 2023-01-03 -> 2023-01-04
# gain 1000.0
# length 1
# 日期變更，清空已存資料: 2023-01-04 -> 2023-01-05
# gain 1000.0
# length 1
# 日期變更，清空已存資料: 2023-01-05 -> 2023-01-06
# gain 1000.0
# length 1
# 日期變更，清空已存資料: 2023-01-06 -> 2023-01-09
# gain 1000.0
# length 1
# 日期變更，清空已存資料: 2023-01-09 -> 2023-01-10
# gain 1000.0
# length 1
# 日期變更，清空已存資料: 2023-01-10 -> 2023-01-11
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-01-11 -> 2023-01-12
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-01-12 -> 2023-01-13
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-01-13 -> 2023-01-16
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-01-16 -> 2023-01-17
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-01-17 -> 2023-01-30
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-01-30 -> 2023-01-31
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-01-31 -> 2023-02-01
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-01 -> 2023-02-02
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-02 -> 2023-02-03
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-03 -> 2023-02-06
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-06 -> 2023-02-07
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-07 -> 2023-02-08
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-08 -> 2023-02-09
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-09 -> 2023-02-10
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-10 -> 2023-02-13
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-13 -> 2023-02-14
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-14 -> 2023-02-15
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-15 -> 2023-02-16
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-16 -> 2023-02-17
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-17 -> 2023-02-20
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-20 -> 2023-02-21
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-21 -> 2023-02-22
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-22 -> 2023-02-23
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-23 -> 2023-02-24
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-02-24 -> 2023-03-01
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-01 -> 2023-03-02
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-02 -> 2023-03-03
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-03 -> 2023-03-06
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-06 -> 2023-03-07
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-07 -> 2023-03-08
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-08 -> 2023-03-09
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-09 -> 2023-03-10
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-10 -> 2023-03-13
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-13 -> 2023-03-14
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-14 -> 2023-03-15
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-15 -> 2023-03-16
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-16 -> 2023-03-17
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-17 -> 2023-03-20
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-20 -> 2023-03-21
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-21 -> 2023-03-22
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-22 -> 2023-03-23
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-23 -> 2023-03-24
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-24 -> 2023-03-27
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-27 -> 2023-03-28
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-28 -> 2023-03-29
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-29 -> 2023-03-30
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-30 -> 2023-03-31
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-03-31 -> 2023-04-06
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-06 -> 2023-04-07
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-07 -> 2023-04-10
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-10 -> 2023-04-11
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-11 -> 2023-04-12
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-12 -> 2023-04-13
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-13 -> 2023-04-14
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-14 -> 2023-04-17
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-17 -> 2023-04-18
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-18 -> 2023-04-19
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-19 -> 2023-04-20
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-20 -> 2023-04-21
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-21 -> 2023-04-24
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-24 -> 2023-04-25
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-25 -> 2023-04-26
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-26 -> 2023-04-27
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-27 -> 2023-04-28
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-04-28 -> 2023-05-02
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-02 -> 2023-05-03
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-03 -> 2023-05-04
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-04 -> 2023-05-05
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-05 -> 2023-05-08
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-08 -> 2023-05-09
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-09 -> 2023-05-10
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-10 -> 2023-05-11
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-11 -> 2023-05-12
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-12 -> 2023-05-15
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-15 -> 2023-05-16
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-16 -> 2023-05-17
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-17 -> 2023-05-18
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-18 -> 2023-05-19
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-19 -> 2023-05-22
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-22 -> 2023-05-23
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-23 -> 2023-05-24
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-24 -> 2023-05-25
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-25 -> 2023-05-26
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-26 -> 2023-05-29
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-29 -> 2023-05-30
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-30 -> 2023-05-31
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-05-31 -> 2023-06-01
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-01 -> 2023-06-02
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-02 -> 2023-06-05
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-05 -> 2023-06-06
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-06 -> 2023-06-07
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-07 -> 2023-06-08
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-08 -> 2023-06-09
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-09 -> 2023-06-12
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-12 -> 2023-06-13
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-13 -> 2023-06-14
# gain -500.0
# length 2
# 日期變更，清空已存資料: 2023-06-14 -> 2023-06-15
# gain 2500.0
# length 3
# 日期變更，清空已存資料: 2023-06-15 -> 2023-06-16
# gain 2500.0
# length 3
# 日期變更，清空已存資料: 2023-06-16 -> 2023-06-19
# gain 7500.0
# length 4
# 日期變更，清空已存資料: 2023-06-19 -> 2023-06-20
# gain 7500.0
# length 4
# 日期變更，清空已存資料: 2023-06-20 -> 2023-06-21
# gain 7500.0
# length 4
# 日期變更，清空已存資料: 2023-06-21 -> 2023-06-26
# gain 10000.0
# length 5
# 日期變更，清空已存資料: 2023-06-26 -> 2023-06-27
# gain 12000.0
# length 6
# 日期變更，清空已存資料: 2023-06-27 -> 2023-06-28
# gain 11000.0
# length 7
# 日期變更，清空已存資料: 2023-06-28 -> 2023-06-29
# gain 11000.0
# length 7
# 日期變更，清空已存資料: 2023-06-29 -> 2023-06-30
# gain 10000.0
# length 8
# 日期變更，清空已存資料: 2023-06-30 -> 2023-07-03
# gain 10000.0
# length 8
# 日期變更，清空已存資料: 2023-07-03 -> 2023-07-04
# gain 10000.0
# length 8
# 日期變更，清空已存資料: 2023-07-04 -> 2023-07-05
# gain 10000.0
# length 8
# 日期變更，清空已存資料: 2023-07-05 -> 2023-07-06
# gain 10000.0
# length 8
# 日期變更，清空已存資料: 2023-07-06 -> 2023-07-07
# gain 9000.0
# length 9
# 日期變更，清空已存資料: 2023-07-07 -> 2023-07-10
# gain 8000.0
# length 10
# 日期變更，清空已存資料: 2023-07-10 -> 2023-07-11
# gain 8000.0
# length 10
# 日期變更，清空已存資料: 2023-07-11 -> 2023-07-12
# gain 8000.0
# length 10
# 日期變更，清空已存資料: 2023-07-12 -> 2023-07-13
# gain 8000.0
# length 10
# 日期變更，清空已存資料: 2023-07-13 -> 2023-07-14
# gain 6500.0
# length 11
# 日期變更，清空已存資料: 2023-07-14 -> 2023-07-17
# gain 6500.0
# length 11
# 日期變更，清空已存資料: 2023-07-17 -> 2023-07-18
# gain 6500.0
# length 11
# 日期變更，清空已存資料: 2023-07-18 -> 2023-07-19
# gain 5500.0
# length 12
# 日期變更，清空已存資料: 2023-07-19 -> 2023-07-20
# gain 4500.0
# length 13
# 日期變更，清空已存資料: 2023-07-20 -> 2023-07-21
# gain 4500.0
# length 13
# 日期變更，清空已存資料: 2023-07-21 -> 2023-07-24
# gain 4500.0
# length 13
# 日期變更，清空已存資料: 2023-07-24 -> 2023-07-25
# gain 4500.0
# length 13
# 日期變更，清空已存資料: 2023-07-25 -> 2023-07-26
# gain 4000.0
# length 14
# 日期變更，清空已存資料: 2023-07-26 -> 2023-07-27
# gain 4000.0
# length 15
# 日期變更，清空已存資料: 2023-07-27 -> 2023-07-28
# gain 3000.0
# length 16
# 日期變更，清空已存資料: 2023-07-28 -> 2023-07-31
# gain 3000.0
# length 16
# 日期變更，清空已存資料: 2023-07-31 -> 2023-08-01
# gain 500.0
# length 17
# 日期變更，清空已存資料: 2023-08-01 -> 2023-08-02
# gain -500.0
# length 18
# 日期變更，清空已存資料: 2023-08-02 -> 2023-08-04
# gain -1500.0
# length 19
# 日期變更，清空已存資料: 2023-08-04 -> 2023-08-07
# gain -1500.0
# length 19
# 日期變更，清空已存資料: 2023-08-07 -> 2023-08-08
# gain -3500.0
# length 20
# 日期變更，清空已存資料: 2023-08-08 -> 2023-08-09
# gain -3500.0
# length 20
# 日期變更，清空已存資料: 2023-08-09 -> 2023-08-10
# gain -3500.0
# length 20
# 日期變更，清空已存資料: 2023-08-10 -> 2023-08-11
# gain -3500.0
# length 21
# 日期變更，清空已存資料: 2023-08-11 -> 2023-08-14
# gain -4000.0
# length 22
# 日期變更，清空已存資料: 2023-08-14 -> 2023-08-15
# gain -4000.0
# length 22
# 日期變更，清空已存資料: 2023-08-15 -> 2023-08-16
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-16 -> 2023-08-17
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-17 -> 2023-08-18
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-18 -> 2023-08-21
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-21 -> 2023-08-22
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-22 -> 2023-08-23
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-23 -> 2023-08-24
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-24 -> 2023-08-25
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-25 -> 2023-08-28
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-28 -> 2023-08-29
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-29 -> 2023-08-30
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-30 -> 2023-08-31
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-08-31 -> 2023-09-01
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-01 -> 2023-09-04
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-04 -> 2023-09-05
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-05 -> 2023-09-06
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-06 -> 2023-09-07
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-07 -> 2023-09-08
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-08 -> 2023-09-11
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-11 -> 2023-09-12
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-12 -> 2023-09-13
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-13 -> 2023-09-14
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-14 -> 2023-09-15
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-15 -> 2023-09-18
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-18 -> 2023-09-19
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-19 -> 2023-09-20
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-20 -> 2023-09-21
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-21 -> 2023-09-22
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-22 -> 2023-09-25
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-25 -> 2023-09-26
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-26 -> 2023-09-27
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-27 -> 2023-09-28
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-09-28 -> 2023-10-02
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-02 -> 2023-10-03
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-03 -> 2023-10-04
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-04 -> 2023-10-05
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-05 -> 2023-10-06
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-06 -> 2023-10-11
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-11 -> 2023-10-12
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-12 -> 2023-10-13
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-13 -> 2023-10-16
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-16 -> 2023-10-17
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-17 -> 2023-10-18
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-18 -> 2023-10-19
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-19 -> 2023-10-20
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-20 -> 2023-10-23
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-23 -> 2023-10-24
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-24 -> 2023-10-25
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-25 -> 2023-10-26
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-26 -> 2023-10-27
# gain -5000.0
# length 23
# 日期變更，清空已存資料: 2023-10-27 -> 2023-10-30
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-10-30 -> 2023-10-31
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-10-31 -> 2023-11-01
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-01 -> 2023-11-02
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-02 -> 2023-11-03
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-03 -> 2023-11-06
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-06 -> 2023-11-07
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-07 -> 2023-11-08
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-08 -> 2023-11-09
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-09 -> 2023-11-10
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-10 -> 2023-11-13
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-13 -> 2023-11-14
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-14 -> 2023-11-15
# gain -5500.0
# length 24
# 日期變更，清空已存資料: 2023-11-15 -> 2023-11-16
# gain -3500.0
# length 25
# 日期變更，清空已存資料: 2023-11-16 -> 2023-11-17
# gain -4500.0
# length 26
# 日期變更，清空已存資料: 2023-11-17 -> 2023-11-20
# gain -4500.0
# length 26
# 日期變更，清空已存資料: 2023-11-20 -> 2023-11-21
# gain -4500.0
# length 26
# 日期變更，清空已存資料: 2023-11-21 -> 2023-11-22
# gain -4500.0
# length 26
# 日期變更，清空已存資料: 2023-11-22 -> 2023-11-23
# gain -4500.0
# length 26
# 日期變更，清空已存資料: 2023-11-23 -> 2023-11-24
# gain -4500.0
# length 26
# 日期變更，清空已存資料: 2023-11-24 -> 2023-11-27
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-11-27 -> 2023-11-28
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-11-28 -> 2023-11-29
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-11-29 -> 2023-11-30
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-11-30 -> 2023-12-01
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-01 -> 2023-12-04
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-04 -> 2023-12-05
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-05 -> 2023-12-06
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-06 -> 2023-12-07
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-07 -> 2023-12-08
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-08 -> 2023-12-11
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-11 -> 2023-12-12
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-12 -> 2023-12-13
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-13 -> 2023-12-14
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-14 -> 2023-12-15
# gain -2500.0
# length 27
# 日期變更，清空已存資料: 2023-12-15 -> 2023-12-18
# gain -3500.0
# length 28
# 日期變更，清空已存資料: 2023-12-18 -> 2023-12-19
# gain -3500.0
# length 28
# 日期變更，清空已存資料: 2023-12-19 -> 2023-12-20
# gain -3500.0
# length 28
# 日期變更，清空已存資料: 2023-12-20 -> 2023-12-21
# gain -3500.0
# length 28
# 日期變更，清空已存資料: 2023-12-21 -> 2023-12-22
# gain -3500.0
# length 28
# 日期變更，清空已存資料: 2023-12-22 -> 2023-12-25
# gain -3500.0
# length 28
# 日期變更，清空已存資料: 2023-12-25 -> 2023-12-26
# gain -3500.0
# length 28
# 日期變更，清空已存資料: 2023-12-26 -> 2023-12-27
# gain -3500.0
# length 28
# 日期變更，清空已存資料: 2023-12-27 -> 2023-12-28
# gain -3500.0
# length 28
# 日期變更，清空已存資料: 2023-12-28 -> 2023-12-29
# gain -3500.0
# length 28

# %%
backtest(start_date="2024-01-01", end_date="2024-11-30",year="2024")
# Out:
# 日期變更，清空已存資料: 2024-01-02 -> 2024-01-03
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-03 -> 2024-01-04
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-04 -> 2024-01-05
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-05 -> 2024-01-08
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-08 -> 2024-01-09
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-09 -> 2024-01-10
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-10 -> 2024-01-11
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-11 -> 2024-01-12
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-12 -> 2024-01-15
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-15 -> 2024-01-16
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-16 -> 2024-01-17
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-17 -> 2024-01-18
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-18 -> 2024-01-19
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-19 -> 2024-01-22
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-22 -> 2024-01-23
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-23 -> 2024-01-24
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-24 -> 2024-01-25
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-25 -> 2024-01-26
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-26 -> 2024-01-29
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-29 -> 2024-01-30
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-30 -> 2024-01-31
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-01-31 -> 2024-02-01
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-02-01 -> 2024-02-02
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-02-02 -> 2024-02-05
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-02-05 -> 2024-02-15
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-02-15 -> 2024-02-16
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-02-16 -> 2024-02-19
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-02-19 -> 2024-02-20
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-02-20 -> 2024-02-21
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-02-21 -> 2024-02-22
# gain -1000.0
# length 1
# 日期變更，清空已存資料: 2024-02-22 -> 2024-02-23
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-02-23 -> 2024-02-26
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-02-26 -> 2024-02-27
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-02-27 -> 2024-02-29
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-02-29 -> 2024-03-01
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-01 -> 2024-03-04
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-04 -> 2024-03-05
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-05 -> 2024-03-06
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-06 -> 2024-03-07
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-07 -> 2024-03-08
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-08 -> 2024-03-11
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-11 -> 2024-03-12
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-12 -> 2024-03-13
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-13 -> 2024-03-14
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-14 -> 2024-03-15
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-15 -> 2024-03-18
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-18 -> 2024-03-19
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-19 -> 2024-03-20
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-20 -> 2024-03-21
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-21 -> 2024-03-22
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-22 -> 2024-03-25
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-25 -> 2024-03-26
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-26 -> 2024-03-27
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-27 -> 2024-03-28
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-28 -> 2024-03-29
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-03-29 -> 2024-04-01
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-01 -> 2024-04-02
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-02 -> 2024-04-03
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-03 -> 2024-04-08
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-08 -> 2024-04-09
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-09 -> 2024-04-10
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-10 -> 2024-04-11
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-11 -> 2024-04-12
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-12 -> 2024-04-15
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-15 -> 2024-04-16
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-16 -> 2024-04-17
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-17 -> 2024-04-18
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-18 -> 2024-04-19
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-19 -> 2024-04-22
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-22 -> 2024-04-23
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-23 -> 2024-04-24
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-24 -> 2024-04-25
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-25 -> 2024-04-26
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-26 -> 2024-04-29
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-29 -> 2024-04-30
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-04-30 -> 2024-05-02
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-02 -> 2024-05-03
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-03 -> 2024-05-06
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-06 -> 2024-05-07
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-07 -> 2024-05-08
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-08 -> 2024-05-09
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-09 -> 2024-05-10
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-10 -> 2024-05-13
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-13 -> 2024-05-14
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-14 -> 2024-05-15
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-15 -> 2024-05-16
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-16 -> 2024-05-17
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-17 -> 2024-05-20
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-20 -> 2024-05-21
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-21 -> 2024-05-22
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-22 -> 2024-05-23
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-23 -> 2024-05-24
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-24 -> 2024-05-27
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-27 -> 2024-05-28
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-28 -> 2024-05-29
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-29 -> 2024-05-30
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-30 -> 2024-05-31
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-05-31 -> 2024-06-03
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-03 -> 2024-06-04
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-04 -> 2024-06-05
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-05 -> 2024-06-06
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-06 -> 2024-06-07
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-07 -> 2024-06-11
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-11 -> 2024-06-12
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-12 -> 2024-06-13
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-13 -> 2024-06-14
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-14 -> 2024-06-17
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-17 -> 2024-06-18
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-18 -> 2024-06-19
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-19 -> 2024-06-20
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-20 -> 2024-06-21
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-21 -> 2024-06-24
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-24 -> 2024-06-25
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-25 -> 2024-06-26
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-26 -> 2024-06-27
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-27 -> 2024-06-28
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-06-28 -> 2024-07-01
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-07-01 -> 2024-07-02
# gain -1500.0
# length 2
# 日期變更，清空已存資料: 2024-07-02 -> 2024-07-03
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-03 -> 2024-07-04
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-04 -> 2024-07-05
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-05 -> 2024-07-08
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-08 -> 2024-07-09
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-09 -> 2024-07-10
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-10 -> 2024-07-11
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-11 -> 2024-07-12
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-12 -> 2024-07-15
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-15 -> 2024-07-16
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-16 -> 2024-07-17
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-17 -> 2024-07-18
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-18 -> 2024-07-19
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-19 -> 2024-07-22
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-22 -> 2024-07-23
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-23 -> 2024-07-26
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-26 -> 2024-07-29
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-29 -> 2024-07-30
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-30 -> 2024-07-31
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-07-31 -> 2024-08-01
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-01 -> 2024-08-02
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-02 -> 2024-08-05
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-05 -> 2024-08-06
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-06 -> 2024-08-07
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-07 -> 2024-08-08
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-08 -> 2024-08-09
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-09 -> 2024-08-12
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-12 -> 2024-08-13
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-13 -> 2024-08-14
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-14 -> 2024-08-15
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-15 -> 2024-08-16
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-16 -> 2024-08-19
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-19 -> 2024-08-20
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-20 -> 2024-08-21
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-21 -> 2024-08-22
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-22 -> 2024-08-23
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-23 -> 2024-08-26
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-26 -> 2024-08-27
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-27 -> 2024-08-28
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-28 -> 2024-08-29
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-29 -> 2024-08-30
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-08-30 -> 2024-09-02
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-02 -> 2024-09-03
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-03 -> 2024-09-04
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-04 -> 2024-09-05
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-05 -> 2024-09-06
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-06 -> 2024-09-09
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-09 -> 2024-09-10
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-10 -> 2024-09-11
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-11 -> 2024-09-12
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-12 -> 2024-09-13
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-13 -> 2024-09-16
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-16 -> 2024-09-18
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-18 -> 2024-09-19
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-19 -> 2024-09-20
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-20 -> 2024-09-23
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-23 -> 2024-09-24
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-24 -> 2024-09-25
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-25 -> 2024-09-26
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-26 -> 2024-09-27
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-27 -> 2024-09-30
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-09-30 -> 2024-10-01
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-01 -> 2024-10-04
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-04 -> 2024-10-07
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-07 -> 2024-10-08
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-08 -> 2024-10-09
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-09 -> 2024-10-11
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-11 -> 2024-10-14
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-14 -> 2024-10-15
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-15 -> 2024-10-16
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-16 -> 2024-10-17
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-17 -> 2024-10-18
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-18 -> 2024-10-21
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-21 -> 2024-10-22
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-22 -> 2024-10-23
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-23 -> 2024-10-24
# gain -2000.0
# length 3
# 日期變更，清空已存資料: 2024-10-24 -> 2024-10-25
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-10-25 -> 2024-10-28
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-10-28 -> 2024-10-29
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-10-29 -> 2024-10-30
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-10-30 -> 2024-11-01
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-01 -> 2024-11-04
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-04 -> 2024-11-05
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-05 -> 2024-11-06
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-06 -> 2024-11-07
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-07 -> 2024-11-08
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-08 -> 2024-11-11
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-11 -> 2024-11-12
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-12 -> 2024-11-13
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-13 -> 2024-11-14
# gain -2500.0
# length 4
# 日期變更，清空已存資料: 2024-11-14 -> 2024-11-15
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-15 -> 2024-11-18
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-18 -> 2024-11-19
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-19 -> 2024-11-20
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-20 -> 2024-11-21
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-21 -> 2024-11-22
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-22 -> 2024-11-25
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-25 -> 2024-11-26
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-26 -> 2024-11-27
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-27 -> 2024-11-28
# gain -2000.0
# length 5
# 日期變更，清空已存資料: 2024-11-28 -> 2024-11-29
# gain -2000.0
# length 5
# [date         2024-12-01 09:01:00
# open                       388.0
# high                       388.0
# low                        388.0
# close                      388.0
# volume                         1
# tic                      2308.TW
# date_only             2024-12-01
# Name: 106110, dtype: object, date         2024-12-01 09:01:00
# open                        47.9
# high                        47.9
# low                         47.9
# close                       47.9
# volume                        52
# tic                      2303.TW
# date_only             2024-12-01
# Name: 247861, dtype: object, date         2024-12-01 09:01:00
# open                       197.5
# high                       198.5
# low                        196.0
# close                      196.5
# volume                        37
# tic                      2317.TW
# date_only             2024-12-01
# Name: 355053, dtype: object, date         2024-12-01 09:01:00
# open                      1000.0
# high                      1020.0
# low                       1000.0
# close                     1000.0
# volume                        25
# tic                      2330.TW
# date_only             2024-12-01
# Name: 446855, dtype: object, date         2024-12-01 09:01:00
# open                      1260.0
# high                      1260.0
# low                       1255.0
# close                     1255.0
# volume                         2
# tic                      2454.TW
# date_only             2024-12-01
# Name: 711187, dtype: object, date         2024-12-01 09:01:00
# open                        88.0
# high                        88.0
# low                         88.0
# close                       88.0
# volume                         4
# tic                      2881.TW
# date_only             2024-12-01
# Name: 881828, dtype: object, date         2024-12-01 09:01:00
# open                        72.0
# high                        72.0
# low                         70.0
# close                       70.0
# volume                        19
# tic                      2882.TW
# date_only             2024-12-01
# Name: 1010620, dtype: object, date         2024-12-01 09:01:00
# open                        40.0
# high                        40.0
# low                         40.0
# close                       40.0
# volume                         8
# tic                      2891.TW
# date_only             2024-12-01
# Name: 1122941, dtype: object]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 backtest(start_date="2024-01-01", end_date="2024-12-15",year="2024")
#
# Cell In[6], line 61, in backtest(start_date, end_date, year)
#      59 if len(time_data) != len(stock_list) and len(time_data) != 0:
#      60     print(time_data)
# ---> 61     raise ValueError("error processing for stock_length")
#      63 # 如果該時間點有資料，傳遞給策略函數
#      64 if time_data:
#
# ValueError: error processing for stock_length
